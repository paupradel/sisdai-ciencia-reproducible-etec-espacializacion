# %%
import os
import geopandas as gpd
import sys
sys.path.append('../')
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning, module="pyogrio")
from modulos.importar_02 import *
from modulos.procesos import *
from modulos.importar import *

# %%
gdf = gpkg()
# Out:
# Archivo:
#  /home/sear/Documentos/integracion_capas/42_250724_niveles_presas/capas/niveles_presas_2021_inegi.gpkg
#
# Dimensiones de la tabla -->  (210, 389)
#
# ...

# %%
campos = list(gdf.columns)
type(campos)
# Out:
# list

# %%
print(campos)
# Out:
# ['g_id', 'nom_ent', 'cve_ent', 'nom_mun', 'cve_mun', 'cvegeomun', 'clavesih', 'nombreoficial', 'nombrecomun', 'estado', 'nommunicipio', 'regioncna', 'uso', 'corriente', 'tipovertedor', 'inicioop', 'elevcorona', 'bordolibre', 'nameelev', 'namealmac', 'namoelev', 'namoalmac', 'alturacortina', '2021_01_01', '2021_01_02', '2021_01_03', '2021_01_04', '2021_01_05', '2021_01_06', '2021_01_07', '2021_01_08', '2021_01_09', '2021_01_10', '2021_01_11', '2021_01_12', '2021_01_13', '2021_01_14', '2021_01_15', '2021_01_16', '2021_01_17', '2021_01_18', '2021_01_19', '2021_01_20', '2021_01_21', '2021_01_22', '2021_01_23', '2021_01_24', '2021_01_25', '2021_01_26', '2021_01_27', '2021_01_28', '2021_01_29', '2021_01_30', '2021_01_31', '2021_02_01', '2021_02_02', '2021_02_03', '2021_02_04', '2021_02_05', '2021_02_06', '2021_02_07', '2021_02_08', '2021_02_09', '2021_02_10', '2021_02_11', '2021_02_12', '2021_02_13', '2021_02_14', '2021_02_15', '2021_02_16', '2021_02_17', '2021_02_18', '2021_02_19', '2021_
# ...

# %%
# mostramos los campos a los que se les va anexar la cadena --> "porc_"
campos_1 = campos[23:-3]
print(campos_1)
# Out:
# ['2021_01_01', '2021_01_02', '2021_01_03', '2021_01_04', '2021_01_05', '2021_01_06', '2021_01_07', '2021_01_08', '2021_01_09', '2021_01_10', '2021_01_11', '2021_01_12', '2021_01_13', '2021_01_14', '2021_01_15', '2021_01_16', '2021_01_17', '2021_01_18', '2021_01_19', '2021_01_20', '2021_01_21', '2021_01_22', '2021_01_23', '2021_01_24', '2021_01_25', '2021_01_26', '2021_01_27', '2021_01_28', '2021_01_29', '2021_01_30', '2021_01_31', '2021_02_01', '2021_02_02', '2021_02_03', '2021_02_04', '2021_02_05', '2021_02_06', '2021_02_07', '2021_02_08', '2021_02_09', '2021_02_10', '2021_02_11', '2021_02_12', '2021_02_13', '2021_02_14', '2021_02_15', '2021_02_16', '2021_02_17', '2021_02_18', '2021_02_19', '2021_02_20', '2021_02_21', '2021_02_22', '2021_02_23', '2021_02_24', '2021_02_25', '2021_02_26', '2021_02_27', '2021_02_28', '2021_03_01', '2021_03_02', '2021_03_03', '2021_03_04', '2021_03_05', '2021_03_06', '2021_03_07', '2021_03_08', '2021_03_09', '2021_03_10', '2021_03_11', '2021_03_12', '20
# ...

# %%
round(gdf2.iloc[0, 25], 4)
# Out:
# np.float64(0.3424)

# %%
gdf2.iloc[0, 25], 4
# Out:
# (np.float64(0.342376695630431), 4)

# %%
gdf2.shape
# Out:
# (210, 389)

# %%
gdf2.iloc[0, 388]
# Out:
# <POINT (-102.428 21.917)>

# %%
campos[16]
# Out:
# 'elevcorona'

# %%
for i in range(16, 388):
    for j in range(len(gdf2)):
        gdf2.iat[j, i] = round(gdf2.iloc[j, i], 4)

# %%
gdf2.head()
# Out:
#    g_id          nom_ent cve_ent      nom_mun cve_mun cvegeomun clavesih  \
# 0     1   Aguascalientes      01  Jesús María     005     01005    ABRAG
# 1     2  Baja California      02      Tijuana     004     02004    ALRBN
# 2     3           Sonora      26   Hermosillo     030     26030    ARLSO
# 3     4        Chihuahua      08     Guerrero     031     08031    AGZCH
# 4     5          Jalisco      14     Huejúcar     041     14041    ACHZC
#
#                     nombreoficial                  nombrecomun  \
# 0     Abelardo L. Rodríguez, Ags.  Abelardo L. Rodríguez, Ags.
# 1     Abelardo L. Rodríguez, B.C.                Tijuana, B.C.
# 2  Abelardo Rodríguez Luján, Son.             Hermosillo, Son.
# 3         Abraham González, Chih.             Guadalupe, Chih.
# 4                   Achimec, Jal.               Vaqueros, Jal.
#
#             estado  ... porc_2021_12_25 porc_2021_12_26 porc_2021_12_27  \
# ...

# %%
dicc = {"estado": "nom_entidad","nommunicipio": "nom_municipio"}
gdf2 = renombrar_columnas(gdf2, dicc)

# %%
campos = list(gdf2.columns)

# %%
print(campos)
# Out:
# ['g_id', 'nom_ent', 'cve_ent', 'nom_mun', 'cve_mun', 'cvegeomun', 'clavesih', 'nombreoficial', 'nombrecomun', 'nom_entidad', 'nom_municipio', 'regioncna', 'uso', 'corriente', 'tipovertedor', 'inicioop', 'elevcorona', 'bordolibre', 'nameelev', 'namealmac', 'namoelev', 'namoalmac', 'alturacortina', 'porc_2021_01_01', 'porc_2021_01_02', 'porc_2021_01_03', 'porc_2021_01_04', 'porc_2021_01_05', 'porc_2021_01_06', 'porc_2021_01_07', 'porc_2021_01_08', 'porc_2021_01_09', 'porc_2021_01_10', 'porc_2021_01_11', 'porc_2021_01_12', 'porc_2021_01_13', 'porc_2021_01_14', 'porc_2021_01_15', 'porc_2021_01_16', 'porc_2021_01_17', 'porc_2021_01_18', 'porc_2021_01_19', 'porc_2021_01_20', 'porc_2021_01_21', 'porc_2021_01_22', 'porc_2021_01_23', 'porc_2021_01_24', 'porc_2021_01_25', 'porc_2021_01_26', 'porc_2021_01_27', 'porc_2021_01_28', 'porc_2021_01_29', 'porc_2021_01_30', 'porc_2021_01_31', 'porc_2021_02_01', 'porc_2021_02_02', 'porc_2021_02_03', 'porc_2021_02_04', 'porc_2021_02_05', 'porc_2021_02_06
'porc_2024_08_16', 'porc_2024_08_17', 'porc_2024_08_18', 'porc_2024_08_19', 'porc_2024_08_20', 'porc_2024_08_21', 'porc_2024_08_22', 'porc_2024_08_23', 'porc_2024_08_24', 'porc_2024_08_25', 'porc_2024_08_26', 'porc_2024_08_27', 'porc_2024_08_28', 'porc_2024_08_29', 'porc_2024_08_30', 'porc_2024_08_31', 'porc_2024_09_01', 'porc_2024_09_02', 'porc_2024_09_03', 'porc_2024_09_04', 'porc_2024_09_05', 'porc_2024_09_06', 'porc_2024_09_07', 'porc_2024_09_08', 'porc_2024_09_09', 'porc_2024_09_10', 'porc_2024_09_11', 'porc_2024_09_12', 'porc_2024_09_13', 'porc_2024_09_14', 'porc_2024_09_15', 'porc_2024_09_16', 'porc_2024_09_17', 'porc_2024_09_18', 'porc_2024_09_19', 'porc_2024_09_20', 'porc_2024_09_21', 'porc_2024_09_22', 'porc_2024_09_23', 'porc_2024_09_24', 'porc_2024_09_25', 'porc_2024_09_26', 'porc_2024_09_27', 'porc_2024_09_28', 'porc_2024_09_29', 'porc_2024_09_30', 'porc_2024_10_01', 'porc_2024_10_02', 'porc_2024_10_03', 'porc_2024_10_04', 'porc_2024_10_05', 'porc_2024_10_06', 'porc_2024_10_07', 'porc_2024_10_08', 'porc_2024_10_09', 'porc_2024_10_10', 'x_long', 'y_lat', 'geometry']

# %%
salida = reordenar_columnas(gdf2, campos)

# %%
campos = list(salida.columns)

# %%
salida_2 = gdf2.sort_values('cvegeomun')

# %%
salida_2.head(25)
# Out:
#      g_id               nom_ent cve_ent             nom_mun cve_mun cvegeomun  \
# 48     49        Aguascalientes      01      Aguascalientes     001     01001
# 102   103        Aguascalientes      01            Calvillo     003     01003
# 144   145        Aguascalientes      01            Calvillo     003     01003
# 0       1        Aguascalientes      01         Jesús María     005     01005
# 33     34        Aguascalientes      01     Rincón de Romos     007     01007
# 90     91        Aguascalientes      01  San José de Gracia     008     01008
# 21     22        Aguascalientes      01  San José de Gracia     008     01008
# 159   160        Aguascalientes      01  San José de Gracia     008     01008
# 56     57       Baja California      02            Ensenada     001     02001
# 122   123       Baja California      02              Tecate     003     02003
# 1       2       Baja California      02             Tijuana     004     02004
# ...

# %%
salida_2.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
ruta = "/home/sear/Documentos/integracion_capas/42_250724_niveles_presas/niveles_presas_2021_inegi_.gpkg"

# %%
lista_eliminar = ["g_id"]
salida_3 = eliminar_columnas(salida_2, lista_eliminar)

# %%
salida_3 = crea_gid(salida_3)

# %%
salida_3.head()
# Out:
#      g_id         nom_ent cve_ent          nom_mun cve_mun cvegeomun clavesih  \
# 48      1  Aguascalientes      01   Aguascalientes     001     01001    NGRAG
# 102     2  Aguascalientes      01         Calvillo     003     01003    CDRAG
# 144     3  Aguascalientes      01         Calvillo     003     01003    MNLAG
# 0       4  Aguascalientes      01      Jesús María     005     01005    ABRAG
# 33      5  Aguascalientes      01  Rincón de Romos     007     01007    PTRAG
#
#                    nombreoficial                  nombrecomun     nom_entidad  \
# 48              El Niágara, Ags.             El Niágara, Ags.  Aguascalientes
# 102            La Codorniz, Ags.            La Codorniz, Ags.  Aguascalientes
# 144             Media Luna, Ags.             Media Luna, Ags.  Aguascalientes
# 0    Abelardo L. Rodríguez, Ags.  Abelardo L. Rodríguez, Ags.  Aguascalientes
# 33     Derivadora Pabellón, Ags.    Derecha Potrerillos, Ags.  Aguascalientes
#
# ...

# %%
salida_3 = salida_3.to_crs(epsg=4326)

# %%
campos = list(salida_3.columns)
print(campos)
# Out:
# ['g_id', 'nom_ent', 'cve_ent', 'nom_mun', 'cve_mun', 'cvegeomun', 'clavesih', 'nombreoficial', 'nombrecomun', 'nom_entidad', 'nom_municipio', 'regioncna', 'uso', 'corriente', 'tipovertedor', 'inicioop', 'elevcorona', 'bordolibre', 'nameelev', 'namealmac', 'namoelev', 'namoalmac', 'alturacortina', 'porc_2021_01_01', 'porc_2021_01_02', 'porc_2021_01_03', 'porc_2021_01_04', 'porc_2021_01_05', 'porc_2021_01_06', 'porc_2021_01_07', 'porc_2021_01_08', 'porc_2021_01_09', 'porc_2021_01_10', 'porc_2021_01_11', 'porc_2021_01_12', 'porc_2021_01_13', 'porc_2021_01_14', 'porc_2021_01_15', 'porc_2021_01_16', 'porc_2021_01_17', 'porc_2021_01_18', 'porc_2021_01_19', 'porc_2021_01_20', 'porc_2021_01_21', 'porc_2021_01_22', 'porc_2021_01_23', 'porc_2021_01_24', 'porc_2021_01_25', 'porc_2021_01_26', 'porc_2021_01_27', 'porc_2021_01_28', 'porc_2021_01_29', 'porc_2021_01_30', 'porc_2021_01_31', 'porc_2021_02_01', 'porc_2021_02_02', 'porc_2021_02_03', 'porc_2021_02_04', 'porc_2021_02_05', 'porc_2021_02_06
# ...

# %%
salida_3['tipovertedor'].unique()
# Out:
# array(['Libre', 'Contr', 'Mixto'], dtype=object)

# %%
salida_3['uso'].unique()
# Out:
# array(['RI', 'AP/RI', 'AP', 'GH', 'GH/RI', 'AP/GH/RI', 'RI/GH', 'CA',
#        'RI/AP', '-999'], dtype=object)

# %%
salida_3.insert(13, 'uso_desc', '')

# %%
salida_3.insert(16, 'tipovertedor_desc', '')

# %%
dicc_tv = {'Libre': 'Libre', 'Contr': 'Controlado', 'Mixto': 'Mixto'}
dicc_uso = {'RI': 'Riego', 'AP/RI': 'Abastecimiento público/Riego', 'AP': 'Abastecimiento público', 'GH': 'Generación hidroeléctrica', 
            'GH/RI': 'Generación hidroeléctrica/Riego', 'AP/GH/RI': 'Abastecimiento público/Generación hidroeléctrica/Riego',
            'RI/GH': 'Riego/Generación hidroeléctrica', 'CA': 'Control de inundaciones', 'RI/AP': 'Riego/Abastecimiento público', '-999': '-999'}
for i in range(len(salida_3)):
    salida_3.iat[i, 13] = dicc_uso[salida_3.iloc[i, 12]]
    salida_3.iat[i, 16] = dicc_tv[salida_3.iloc[i, 15]]

# %%
salida_3.head()
# Out:
#      g_id         nom_ent cve_ent          nom_mun cve_mun cvegeomun clavesih  \
# 48      1  Aguascalientes      01   Aguascalientes     001     01001    NGRAG
# 102     2  Aguascalientes      01         Calvillo     003     01003    CDRAG
# 144     3  Aguascalientes      01         Calvillo     003     01003    MNLAG
# 0       4  Aguascalientes      01      Jesús María     005     01005    ABRAG
# 33      5  Aguascalientes      01  Rincón de Romos     007     01007    PTRAG
#
#                    nombreoficial                  nombrecomun     nom_entidad  \
# 48              El Niágara, Ags.             El Niágara, Ags.  Aguascalientes
# 102            La Codorniz, Ags.            La Codorniz, Ags.  Aguascalientes
# 144             Media Luna, Ags.             Media Luna, Ags.  Aguascalientes
# 0    Abelardo L. Rodríguez, Ags.  Abelardo L. Rodríguez, Ags.  Aguascalientes
# 33     Derivadora Pabellón, Ags.    Derecha Potrerillos, Ags.  Aguascalientes
#
# ...

# %%
campos = list(salida_3.columns)
print(campos)
# Out:
# ['g_id', 'nom_ent', 'cve_ent', 'nom_mun', 'cve_mun', 'cvegeomun', 'clavesih', 'nombreoficial', 'nombrecomun', 'nom_entidad', 'nom_municipio', 'regioncna', 'uso', 'uso_desc', 'corriente', 'tipovertedor', 'tipovertedor_desc', 'inicioop', 'elevcorona', 'bordolibre', 'nameelev', 'namealmac', 'namoelev', 'namoalmac', 'alturacortina', 'porc_2021_01_01', 'porc_2021_01_02', 'porc_2021_01_03', 'porc_2021_01_04', 'porc_2021_01_05', 'porc_2021_01_06', 'porc_2021_01_07', 'porc_2021_01_08', 'porc_2021_01_09', 'porc_2021_01_10', 'porc_2021_01_11', 'porc_2021_01_12', 'porc_2021_01_13', 'porc_2021_01_14', 'porc_2021_01_15', 'porc_2021_01_16', 'porc_2021_01_17', 'porc_2021_01_18', 'porc_2021_01_19', 'porc_2021_01_20', 'porc_2021_01_21', 'porc_2021_01_22', 'porc_2021_01_23', 'porc_2021_01_24', 'porc_2021_01_25', 'porc_2021_01_26', 'porc_2021_01_27', 'porc_2021_01_28', 'porc_2021_01_29', 'porc_2021_01_30', 'porc_2021_01_31', 'porc_2021_02_01', 'porc_2021_02_02', 'porc_2021_02_03', 'porc_2021_02_04', 'p
# ...

# %%
for i in range(18, 24):
    for j in range(len(salida_3)):
        salida_3.iat[j, i] = round(salida_3.iloc[j, i], 4)
    print(campos[i])
# Out:
# elevcorona
# bordolibre
# nameelev
# namealmac
# namoelev
# namoalmac

# %%
salida_3 = salida_3.to_crs(epsg=4326)

# %%
ruta = "/home/sear/Documentos/integracion_capas/42_250724_niveles_presas/capas/niveles_presas_2021_inegi.gpkg"

# %%
salida_3.to_file(ruta, layer='niveles_presas_2021', driver="GPKG")
